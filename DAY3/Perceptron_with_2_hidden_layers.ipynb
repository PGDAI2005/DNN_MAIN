# %% [markdown]
# # **Assignment  02**
#
# Name:
# ### **2**
#
# PRN:
# ### **240340128007**
#
# ### **Implement Perceptron with Sigmoid activation Function**

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# %% [markdown]
# ## Import Statements

# %%
###-----------------
### Import Libraries
###-----------------

import os
import sys
sys.path.insert(0, r'G:\My Drive\DNN')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split

import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
 
# from utils.helper import fn_plot_decision_boundary # this function is from helper.py

# %%
# print (fn_plot_decision_boundary.__doc__)

# %% [markdown]
# ## Setup Global Parameters

# %%
###----------------
### Some parameters
###----------------

RANDOM_STATE = 24 # REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE)
rng = np.random.default_rng(seed = RANDOM_STATE) # Set Random Seed for reproducible  results

NOISE = 0.2
EPOCHS = 50000  # number of epochs
ALPHA = 0.1  # learning rate
N_SAMPLES = 1000
TEST_SIZE = 0.2

# parameters for Matplotlib
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'large',
          'axes.titlesize':'large',
          'xtick.labelsize':'large',
          'ytick.labelsize':'large'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %% [markdown]
# ## Generate Data Set
# <div style="font-family: Arial; font-size:1.2em;">
# Sklearn's dataset generator is good source of data for learning. To keep the example simple, I'll suggest  <a href="http://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html">make_moon</a> dataset generator.
# </div>

# %%
X, y = datasets.make_moons(n_samples=N_SAMPLES, 
                           shuffle=True, 
                           noise=NOISE, 
                           random_state=RANDOM_STATE)
X[:5], y[:5]
# Out:
# (array([[ 0.90633951,  0.90267624],
#         [-1.11536828,  0.75579289],
#         [ 1.88769158,  0.4175967 ],
#         [-0.93345034, -0.02299851],
#         [-0.96872877,  0.06396285]]),
#  array([0, 0, 1, 0, 0], dtype=int64))

# %% [markdown]
# ## Visualization
# <p style="font-family: Arial; font-size:1.2em">
# DataFrames are easier to visualize
# </p>

# %%
data_df = pd.DataFrame(X, columns = ['A', 'B'])

data_df['target'] = y

data_df.head()
# Out:
#           A         B  target
# 0  0.906340  0.902676       0
# 1 -1.115368  0.755793       0
# 2  1.887692  0.417597       1
# 3 -0.933450 -0.022999       0
# 4 -0.968729  0.063963       0

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   float64
#  1   B       1000 non-null   float64
#  2   target  1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %%
data_df.describe() # Generate descriptive statistic
# Out:
#                  A            B      target
# count  1000.000000  1000.000000  1000.00000
# mean      0.490841     0.239025     0.50000
# std       0.898951     0.540082     0.50025
# min      -1.688795    -0.955280     0.00000
# 25%      -0.149565    -0.205090     0.00000
# 50%       0.500100     0.241163     0.50000
# 75%       1.095048     0.680394     1.00000
# max       2.419113     1.612075     1.00000

# %%
# what labels are present?
data_df.target.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
fig, ax = plt.subplots() # Instantiate
    
data_df['target'].value_counts().plot(ax=ax, kind='bar');

# %%
# Using Seaborn
ax = sns.scatterplot(data=data_df, # data from dataframe
                     x='A', y='B',  # X axis and y axis columns
                     palette=sns.color_palette("bright", 2), # color map
                     hue='target'); # Color as per target column

# %%
# data_train, data_test = data_df.to_numpy()[:900], data_df.to_numpy()[900:]

# %%
# data_train.shape, data_test.shape

# %%
# rng.random(data_train.shape[1])

# %% [markdown]
# Stochastic Gradient Descent

# %%
# def fn_sigmoid(z):
#     return 1 / (1 + (np.exp(-z)))

# %%
# softmax function 
def fn_softmax(z):
    exp_z = np.exp(z)
    
    return exp_z / np.sum(exp_z, axis=1, keepdims=True)

# %%
sm = fn_softmax(np.asarray([[8,5,0], [-10,0,10]]))
sm.sum(axis=1, keepdims = True).shape
# sm.sum(axis=1).shape
# Out:
# (2, 1)

# %%
# t = fn_sigmoid(np.asarray([[-1, 0, 1], [-np.inf, 0, np.inf]]))
# t

# %%
def fn_activ(x):

    return np.tanh(x)

def fn_activ_prime(x):

    return 1.0 - np.tanh(x)**2

# %%
def predict(model, X_p):

    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    
    ### Forward Propagation

    # Layer 1
    z1 = X_p.dot(W1) + b1 # Aggregation
    a1 = fn_activ(z1) # Activation

    # Layer 2
    z2 = a1.dot(W2) + b2 # Aggregation
    a2 = fn_softmax(z2) # Activation
    
    return np.argmax(a2, axis=1) # pick index of class with highest probability

# %%
def calculate_loss(model, X_l, y_l):
    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    
    m = X_l.shape[0]

    # Layer 1
    z1 = X_l.dot(W1) + b1 # Aggregation z = X.W + b
    a1 = fn_activ(z1) # Activation a = g(z)

    # Layer 2 marked 1
    z2 = a1.dot(W2) + b2 # Aggregation z = X.W + b
    a2 = fn_softmax(z2) # Activation a = g(z)
    
    data_loss = -(y_l*np.log(a2) + (1 - y_l) * np.log(1 - a2)).sum() # Binary 

    return data_loss/m

# %%
loss_hist = {}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def build_model(X_tr, y_tr, nn_hdim, nn_out, alpha=ALPHA ,epochs = EPOCHS):
    '''
    Args:
        X_tr : Training features
        y_tr : Training labels
        nn_hdim : Number of nodes in the hidden layer
        nn_out : Size of output
    '''
    m, nn_input_dim = X_tr.shape
    nn_output_dim = nn_out
    
    # W1 = rng.random.rand((nn_input_dim, nn_hdim), 
    #          dtype = np.float32) / np.sqrt(nn_input_dim)

    # W2 = rng.random.rand((nn_hdim, nn_output_dim), 
    #         dtype = np.float32) / np.sqrt(nn_hdim)

    # size = 2,4
    W1 = np.random.rand(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
    # size = 4,2
    W2 = np.random.rand(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
    # size = 4
    b1 = np.zeros((1, nn_hdim), dtype= np.float32)
    # size = 2
    b2 = np.zeros((1, nn_output_dim), dtype= np.float32)

    curr_loss = 0
    loss, epoch = [], []

    for i in range(0, epochs):
        ### Forward Propagation

        # Layer 1 *marked 3*
        z1 = X_tr.dot(W1) + b1 # Aggregation z = X.W + b
        a1 = fn_activ(z1) # Activation a = g(z)

        # Layer 2 *marked 1*
        z2 = a1.dot(W2) + b2 # Aggregation z = X.W + b
        a2 = fn_softmax(z2) # Activation a = g(z)
    
        # Back Propagation 
        # layer 2 *marked 2* (orange color)
        assert (a2.shape == y_tr.shape), f'check y {a2.shape}/{y_tr.shape}'
        dz2 = a2 - y_tr ## REMEMBER dim of a2 and y to be same

        dW2 = (a1.T).dot(dz2)
        assert(W2.shape == dW2.shape), f'check W2 {W2.shape}/{dW2.shape}'

        db2 = np.sum(dz2, axis= 0 , keepdims = True)
        assert(b2.shape == db2.shape), f'check b2 {b2.shape}/{db2.shape}'

        da1 = dz2.dot(W2.T)
        assert(a1.shape == da1.shape), f'check a1 {a1.shape}/{da1.shape}'

        # Layer1 *marked 4*
        dz1 = da1 * fn_activ_prime(z1)
        assert(z1.shape == dz1.shape), f'check z1 {z1.shape}/{dz1.shape}'
    
        dW1 = (X_tr.T).dot(dz1)
        assert(W1.shape == dW1.shape), f'check W1 {W1.shape}/{dW1.shape}'

        db1 = np.sum(dz1, axis= 0 , keepdims = True) # db = 
        assert(b1.shape == db1.shape), f'check b1 {b1.shape}/{db1.shape}'


        # Gradient Update
        W1 += -alpha * dW1/m
        b1 += -alpha * db1/m
        W2 += -alpha * dW2/m
        b2 += -alpha * db2/m

        model = {'W1': W1, 'b1' : b1,
                 'W2': W2, 'b2' : b2
                 }
    
        curr_loss = calculate_loss(model, X_tr, y_tr)
        loss.append(curr_loss)
        epoch.append(i)
        
        if i%100 == 0:
            print(f'After epoch: {i:3d}; loss: {curr_loss: .5f}')

    loss_hist['epoch'] = epoch
    loss_hist['loss'] = loss

    return model

# %%
loss_hist= {}

# %%
y = pd.get_dummies(y).to_numpy()
y
# Out:
# array([[ True, False],
#        [ True, False],
#        [False,  True],
#        ...,
#        [ True, False],
#        [False,  True],
#        [ True, False]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=TEST_SIZE,
                                                    stratify=y,
                                                    random_state=RANDOM_STATE)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((800, 2), (200, 2), (800, 2), (200, 2))

# %%
print(y_train.shape)
# y_train = y_train.reshape(-1, 1)
# y_train.shape
y_train
# Out:
# (800, 2)
# array([[ True, False],
#        [False,  True],
#        [False,  True],
#        ...,
#        [ True, False],
#        [ True, False],
#        [False,  True]])

# %%
print(y_test.shape)
# Out:
# (200, 2)

# %%
nn_out_dim = 2

model = build_model(X_train, y_train, 4, nn_out_dim)
# Out:
# After epoch:   0; loss:  1.36221
# After epoch: 100; loss:  0.76973
# After epoch: 200; loss:  0.62692
# After epoch: 300; loss:  0.60988
# After epoch: 400; loss:  0.60560
# After epoch: 500; loss:  0.60184
# After epoch: 600; loss:  0.59662
# After epoch: 700; loss:  0.58866
# After epoch: 800; loss:  0.57650
# After epoch: 900; loss:  0.55882
# After epoch: 1000; loss:  0.53547
# After epoch: 1100; loss:  0.50799
# After epoch: 1200; loss:  0.47896
# After epoch: 1300; loss:  0.45062
# After epoch: 1400; loss:  0.42429
# After epoch: 1500; loss:  0.40036
# After epoch: 1600; loss:  0.37860
# After epoch: 1700; loss:  0.35847
# After epoch: 1800; loss:  0.33926
# After epoch: 1900; loss:  0.32030
# After epoch: 2000; loss:  0.30131
# After epoch: 2100; loss:  0.28261
# After epoch: 2200; loss:  0.26496
# After epoch: 2300; loss:  0.24903
# After epoch: 2400; loss:  0.23515
# After epoch: 2500; loss:  0.22329
# After epoch: 2600; loss:  0.21324
# After epoch: 2700; loss:  0.20475
# After epoch: 2800; loss:  0.19755
# After epoch: 2900; loss:  0.19142
# After epoch: 3000; loss:  0.18618
# After epoch: 3100; loss:  0.18167
# After epoch: 3200; loss:  0.17777
# After epoch: 3300; loss:  0.17437
# After epoch: 3400; loss:  0.17140
# After epoch: 3500; loss:  0.16878
# After epoch: 3600; loss:  0.16647
# After epoch: 3700; loss:  0.16441
# After epoch: 3800; loss:  0.16257
# After epoch: 3900; loss:  0.16092
# After epoch: 4000; loss:  0.15943
# After epoch: 4100; loss:  0.15808
# After epoch: 4200; loss:  0.15686
# After epoch: 4300; loss:  0.15574
# After epoch: 4400; loss:  0.15472
# After epoch: 4500; loss:  0.15378
# After epoch: 4600; loss:  0.15291
# After epoch: 4700; loss:  0.15211
# After epoch: 4800; loss:  0.15137
# After epoch: 4900; loss:  0.15068
# After epoch: 5000; loss:  0.15004
# After epoch: 5100; loss:  0.14944
# After epoch: 5200; loss:  0.14887
# After epoch: 5300; loss:  0.14835
# After epoch: 5400; loss:  0.14785
# After epoch: 5500; loss:  0.14738
# After epoch: 5600; loss:  0.14694
# After epoch: 5700; loss:  0.14653
# After epoch: 5800; loss:  0.14613
# After epoch: 5900; loss:  0.14576
# After epoch: 6000; loss:  0.14540
# After epoch: 6100; loss:  0.14507
# After epoch: 6200; loss:  0.14474
# After epoch: 6300; loss:  0.14444
# After epoch: 6400; loss:  0.14414
# After epoch: 6500; loss:  0.14386
# After epoch: 6600; loss:  0.14359
# After epoch: 6700; loss:  0.14334
# After epoch: 6800; loss:  0.14309
# After epoch: 6900; loss:  0.14285
# After epoch: 7000; loss:  0.14262
# After epoch: 7100; loss:  0.14240
# After epoch: 7200; loss:  0.14219
# After epoch: 7300; loss:  0.14199
# After epoch: 7400; loss:  0.14179
# After epoch: 7500; loss:  0.14160
# After epoch: 7600; loss:  0.14142
# After epoch: 7700; loss:  0.14124
# After epoch: 7800; loss:  0.14107
# After epoch: 7900; loss:  0.14090
# After epoch: 8000; loss:  0.14074
# After epoch: 8100; loss:  0.14059
# After epoch: 8200; loss:  0.14044
# After epoch: 8300; loss:  0.14029
# After epoch: 8400; loss:  0.14015
# After epoch: 8500; loss:  0.14001
# After epoch: 8600; loss:  0.13988
# After epoch: 8700; loss:  0.13975
# After epoch: 8800; loss:  0.13962
# After epoch: 8900; loss:  0.13950
# After epoch: 9000; loss:  0.13938
# After epoch: 9100; loss:  0.13926
# After epoch: 9200; loss:  0.13915
# After epoch: 9300; loss:  0.13904
# After epoch: 9400; loss:  0.13893
# After epoch: 9500; loss:  0.13883
# After epoch: 9600; loss:  0.13872
# After epoch: 9700; loss:  0.13862
# After epoch: 9800; loss:  0.13853
# After epoch: 9900; loss:  0.13843
# After epoch: 10000; loss:  0.13834
# After epoch: 10100; loss:  0.13825
# After epoch: 10200; loss:  0.13816
# After epoch: 10300; loss:  0.13807
# After epoch: 10400; loss:  0.13799
# After epoch: 10500; loss:  0.13791
# After epoch: 10600; loss:  0.13783
# After epoch: 10700; loss:  0.13775
# After epoch: 10800; loss:  0.13767
# After epoch: 10900; loss:  0.13760
# After epoch: 11000; loss:  0.13752
# After epoch: 11100; loss:  0.13745
# After epoch: 11200; loss:  0.13738
# After epoch: 11300; loss:  0.13731
# After epoch: 11400; loss:  0.13724
# After epoch: 11500; loss:  0.13718
# After epoch: 11600; loss:  0.13711
# After epoch: 11700; loss:  0.13705
# After epoch: 11800; loss:  0.13699
# After epoch: 11900; loss:  0.13693
# After epoch: 12000; loss:  0.13687
# After epoch: 12100; loss:  0.13681
# After epoch: 12200; loss:  0.13675
# After epoch: 12300; loss:  0.13670
# After epoch: 12400; loss:  0.13664
# After epoch: 12500; loss:  0.13659
# After epoch: 12600; loss:  0.13654
# After epoch: 12700; loss:  0.13648
# After epoch: 12800; loss:  0.13643
# After epoch: 12900; loss:  0.13638
# After epoch: 13000; loss:  0.13633
# After epoch: 13100; loss:  0.13629
# After epoch: 13200; loss:  0.13624
# After epoch: 13300; loss:  0.13619
# After epoch: 13400; loss:  0.13615
# After epoch: 13500; loss:  0.13610
# After epoch: 13600; loss:  0.13606
# After epoch: 13700; loss:  0.13602
# After epoch: 13800; loss:  0.13598
# After epoch: 13900; loss:  0.13593
# After epoch: 14000; loss:  0.13589
# After epoch: 14100; loss:  0.13585
# After epoch: 14200; loss:  0.13582
# After epoch: 14300; loss:  0.13578
# After epoch: 14400; loss:  0.13574
# After epoch: 14500; loss:  0.13570
# After epoch: 14600; loss:  0.13567
# After epoch: 14700; loss:  0.13563
# After epoch: 14800; loss:  0.13560
# After epoch: 14900; loss:  0.13556
# After epoch: 15000; loss:  0.13553
# After epoch: 15100; loss:  0.13549
# After epoch: 15200; loss:  0.13546
# After epoch: 15300; loss:  0.13543
# After epoch: 15400; loss:  0.13540
# After epoch: 15500; loss:  0.13537
# After epoch: 15600; loss:  0.13534
# After epoch: 15700; loss:  0.13530
# After epoch: 15800; loss:  0.13528
# After epoch: 15900; loss:  0.13525
# After epoch: 16000; loss:  0.13522
# After epoch: 16100; loss:  0.13519
# After epoch: 16200; loss:  0.13516
# After epoch: 16300; loss:  0.13513
# After epoch: 16400; loss:  0.13511
# After epoch: 16500; loss:  0.13508
# After epoch: 16600; loss:  0.13505
# After epoch: 16700; loss:  0.13503
# After epoch: 16800; loss:  0.13500
# After epoch: 16900; loss:  0.13498
# After epoch: 17000; loss:  0.13495
# After epoch: 17100; loss:  0.13493
# After epoch: 17200; loss:  0.13491
# After epoch: 17300; loss:  0.13488
# After epoch: 17400; loss:  0.13486
# After epoch: 17500; loss:  0.13484
# After epoch: 17600; loss:  0.13482
# After epoch: 17700; loss:  0.13479
# After epoch: 17800; loss:  0.13477
# After epoch: 17900; loss:  0.13475
# After epoch: 18000; loss:  0.13473
# After epoch: 18100; loss:  0.13471
# After epoch: 18200; loss:  0.13469
# After epoch: 18300; loss:  0.13467
# After epoch: 18400; loss:  0.13465
# After epoch: 18500; loss:  0.13463
# After epoch: 18600; loss:  0.13461
# After epoch: 18700; loss:  0.13459
# After epoch: 18800; loss:  0.13457
# After epoch: 18900; loss:  0.13456
# After epoch: 19000; loss:  0.13454
# After epoch: 19100; loss:  0.13452
# After epoch: 19200; loss:  0.13450
# After epoch: 19300; loss:  0.13448
# After epoch: 19400; loss:  0.13447
# After epoch: 19500; loss:  0.13445
# After epoch: 19600; loss:  0.13443
# After epoch: 19700; loss:  0.13442
# After epoch: 19800; loss:  0.13440
# After epoch: 19900; loss:  0.13438
# After epoch: 20000; loss:  0.13437
# After epoch: 20100; loss:  0.13435
# After epoch: 20200; loss:  0.13434
# After epoch: 20300; loss:  0.13432
# After epoch: 20400; loss:  0.13431
# After epoch: 20500; loss:  0.13429
# After epoch: 20600; loss:  0.13428
# After epoch: 20700; loss:  0.13426
# After epoch: 20800; loss:  0.13425
# After epoch: 20900; loss:  0.13424
# After epoch: 21000; loss:  0.13422
# After epoch: 21100; loss:  0.13421
# After epoch: 21200; loss:  0.13420
# After epoch: 21300; loss:  0.13418
# After epoch: 21400; loss:  0.13417
# After epoch: 21500; loss:  0.13416
# After epoch: 21600; loss:  0.13414
# After epoch: 21700; loss:  0.13413
# After epoch: 21800; loss:  0.13412
# After epoch: 21900; loss:  0.13411
# After epoch: 22000; loss:  0.13409
# After epoch: 22100; loss:  0.13408
# After epoch: 22200; loss:  0.13407
# After epoch: 22300; loss:  0.13406
# After epoch: 22400; loss:  0.13405
# After epoch: 22500; loss:  0.13404
# After epoch: 22600; loss:  0.13402
# After epoch: 22700; loss:  0.13401
# After epoch: 22800; loss:  0.13400
# After epoch: 22900; loss:  0.13399
# After epoch: 23000; loss:  0.13398
# After epoch: 23100; loss:  0.13397
# After epoch: 23200; loss:  0.13396
# After epoch: 23300; loss:  0.13395
# After epoch: 23400; loss:  0.13394
# After epoch: 23500; loss:  0.13393
# After epoch: 23600; loss:  0.13392
# After epoch: 23700; loss:  0.13391
# After epoch: 23800; loss:  0.13390
# After epoch: 23900; loss:  0.13389
# After epoch: 24000; loss:  0.13388
# After epoch: 24100; loss:  0.13387
# After epoch: 24200; loss:  0.13386
# After epoch: 24300; loss:  0.13385
# After epoch: 24400; loss:  0.13384
# After epoch: 24500; loss:  0.13383
# After epoch: 24600; loss:  0.13382
# After epoch: 24700; loss:  0.13381
# After epoch: 24800; loss:  0.13381
# After epoch: 24900; loss:  0.13380
# After epoch: 25000; loss:  0.13379
# After epoch: 25100; loss:  0.13378
# After epoch: 25200; loss:  0.13377
# After epoch: 25300; loss:  0.13376
# After epoch: 25400; loss:  0.13375
# After epoch: 25500; loss:  0.13375
# After epoch: 25600; loss:  0.13374
# After epoch: 25700; loss:  0.13373
# After epoch: 25800; loss:  0.13372
# After epoch: 25900; loss:  0.13371
# After epoch: 26000; loss:  0.13371
# After epoch: 26100; loss:  0.13370
# After epoch: 26200; loss:  0.13369
# After epoch: 26300; loss:  0.13368
# After epoch: 26400; loss:  0.13368
# After epoch: 26500; loss:  0.13367
# After epoch: 26600; loss:  0.13366
# After epoch: 26700; loss:  0.13365
# After epoch: 26800; loss:  0.13365
# After epoch: 26900; loss:  0.13364
# After epoch: 27000; loss:  0.13363
# After epoch: 27100; loss:  0.13363
# After epoch: 27200; loss:  0.13362
# After epoch: 27300; loss:  0.13361
# After epoch: 27400; loss:  0.13360
# After epoch: 27500; loss:  0.13360
# After epoch: 27600; loss:  0.13359
# After epoch: 27700; loss:  0.13358
# After epoch: 27800; loss:  0.13358
# After epoch: 27900; loss:  0.13357
# After epoch: 28000; loss:  0.13357
# After epoch: 28100; loss:  0.13356
# After epoch: 28200; loss:  0.13355
# After epoch: 28300; loss:  0.13355
# After epoch: 28400; loss:  0.13354
# After epoch: 28500; loss:  0.13353
# After epoch: 28600; loss:  0.13353
# After epoch: 28700; loss:  0.13352
# After epoch: 28800; loss:  0.13352
# After epoch: 28900; loss:  0.13351
# After epoch: 29000; loss:  0.13350
# After epoch: 29100; loss:  0.13350
# After epoch: 29200; loss:  0.13349
# After epoch: 29300; loss:  0.13349
# After epoch: 29400; loss:  0.13348
# After epoch: 29500; loss:  0.13347
# After epoch: 29600; loss:  0.13347
# After epoch: 29700; loss:  0.13346
# After epoch: 29800; loss:  0.13346
# After epoch: 29900; loss:  0.13345
# After epoch: 30000; loss:  0.13345
# After epoch: 30100; loss:  0.13344
# After epoch: 30200; loss:  0.13344
# After epoch: 30300; loss:  0.13343
# After epoch: 30400; loss:  0.13343
# After epoch: 30500; loss:  0.13342
# After epoch: 30600; loss:  0.13342
# After epoch: 30700; loss:  0.13341
# After epoch: 30800; loss:  0.13340
# After epoch: 30900; loss:  0.13340
# After epoch: 31000; loss:  0.13339
# After epoch: 31100; loss:  0.13339
# After epoch: 31200; loss:  0.13338
# After epoch: 31300; loss:  0.13338
# After epoch: 31400; loss:  0.13337
# After epoch: 31500; loss:  0.13337
# After epoch: 31600; loss:  0.13337
# After epoch: 31700; loss:  0.13336
# After epoch: 31800; loss:  0.13336
# After epoch: 31900; loss:  0.13335
# After epoch: 32000; loss:  0.13335
# After epoch: 32100; loss:  0.13334
# After epoch: 32200; loss:  0.13334
# After epoch: 32300; loss:  0.13333
# After epoch: 32400; loss:  0.13333
# After epoch: 32500; loss:  0.13332
# After epoch: 32600; loss:  0.13332
# After epoch: 32700; loss:  0.13331
# After epoch: 32800; loss:  0.13331
# After epoch: 32900; loss:  0.13330
# After epoch: 33000; loss:  0.13330
# After epoch: 33100; loss:  0.13330
# After epoch: 33200; loss:  0.13329
# After epoch: 33300; loss:  0.13329
# After epoch: 33400; loss:  0.13328
# After epoch: 33500; loss:  0.13328
# After epoch: 33600; loss:  0.13327
# After epoch: 33700; loss:  0.13327
# After epoch: 33800; loss:  0.13327
# After epoch: 33900; loss:  0.13326
# After epoch: 34000; loss:  0.13326
# After epoch: 34100; loss:  0.13325
# After epoch: 34200; loss:  0.13325
# After epoch: 34300; loss:  0.13325
# After epoch: 34400; loss:  0.13324
# After epoch: 34500; loss:  0.13324
# After epoch: 34600; loss:  0.13323
# After epoch: 34700; loss:  0.13323
# After epoch: 34800; loss:  0.13323
# After epoch: 34900; loss:  0.13322
# After epoch: 35000; loss:  0.13322
# After epoch: 35100; loss:  0.13321
# After epoch: 35200; loss:  0.13321
# After epoch: 35300; loss:  0.13321
# After epoch: 35400; loss:  0.13320
# After epoch: 35500; loss:  0.13320
# After epoch: 35600; loss:  0.13320
# After epoch: 35700; loss:  0.13319
# After epoch: 35800; loss:  0.13319
# After epoch: 35900; loss:  0.13318
# After epoch: 36000; loss:  0.13318
# After epoch: 36100; loss:  0.13318
# After epoch: 36200; loss:  0.13317
# After epoch: 36300; loss:  0.13317
# After epoch: 36400; loss:  0.13317
# After epoch: 36500; loss:  0.13316
# After epoch: 36600; loss:  0.13316
# After epoch: 36700; loss:  0.13315
# After epoch: 36800; loss:  0.13315
# After epoch: 36900; loss:  0.13315
# After epoch: 37000; loss:  0.13314
# After epoch: 37100; loss:  0.13314
# After epoch: 37200; loss:  0.13314
# After epoch: 37300; loss:  0.13313
# After epoch: 37400; loss:  0.13313
# After epoch: 37500; loss:  0.13313
# After epoch: 37600; loss:  0.13312
# After epoch: 37700; loss:  0.13312
# After epoch: 37800; loss:  0.13312
# After epoch: 37900; loss:  0.13311
# After epoch: 38000; loss:  0.13311
# After epoch: 38100; loss:  0.13311
# After epoch: 38200; loss:  0.13310
# After epoch: 38300; loss:  0.13310
# After epoch: 38400; loss:  0.13310
# After epoch: 38500; loss:  0.13309
# After epoch: 38600; loss:  0.13309
# After epoch: 38700; loss:  0.13309
# After epoch: 38800; loss:  0.13308
# After epoch: 38900; loss:  0.13308
# After epoch: 39000; loss:  0.13308
# After epoch: 39100; loss:  0.13307
# After epoch: 39200; loss:  0.13307
# After epoch: 39300; loss:  0.13307
# After epoch: 39400; loss:  0.13306
# After epoch: 39500; loss:  0.13306
# After epoch: 39600; loss:  0.13306
# After epoch: 39700; loss:  0.13306
# After epoch: 39800; loss:  0.13305
# After epoch: 39900; loss:  0.13305
# After epoch: 40000; loss:  0.13305
# After epoch: 40100; loss:  0.13304
# After epoch: 40200; loss:  0.13304
# After epoch: 40300; loss:  0.13304
# After epoch: 40400; loss:  0.13303
# After epoch: 40500; loss:  0.13303
# After epoch: 40600; loss:  0.13303
# After epoch: 40700; loss:  0.13302
# After epoch: 40800; loss:  0.13302
# After epoch: 40900; loss:  0.13302
# After epoch: 41000; loss:  0.13302
# After epoch: 41100; loss:  0.13301
# After epoch: 41200; loss:  0.13301
# After epoch: 41300; loss:  0.13301
# After epoch: 41400; loss:  0.13300
# After epoch: 41500; loss:  0.13300
# After epoch: 41600; loss:  0.13300
# After epoch: 41700; loss:  0.13300
# After epoch: 41800; loss:  0.13299
# After epoch: 41900; loss:  0.13299
# After epoch: 42000; loss:  0.13299
# After epoch: 42100; loss:  0.13298
# After epoch: 42200; loss:  0.13298
# After epoch: 42300; loss:  0.13298
# After epoch: 42400; loss:  0.13298
# After epoch: 42500; loss:  0.13297
# After epoch: 42600; loss:  0.13297
# After epoch: 42700; loss:  0.13297
# After epoch: 42800; loss:  0.13296
# After epoch: 42900; loss:  0.13296
# After epoch: 43000; loss:  0.13296
# After epoch: 43100; loss:  0.13296
# After epoch: 43200; loss:  0.13295
# After epoch: 43300; loss:  0.13295
# After epoch: 43400; loss:  0.13295
# After epoch: 43500; loss:  0.13294
# After epoch: 43600; loss:  0.13294
# After epoch: 43700; loss:  0.13294
# After epoch: 43800; loss:  0.13294
# After epoch: 43900; loss:  0.13293
# After epoch: 44000; loss:  0.13293
# After epoch: 44100; loss:  0.13293
# After epoch: 44200; loss:  0.13293
# After epoch: 44300; loss:  0.13292
# After epoch: 44400; loss:  0.13292
# After epoch: 44500; loss:  0.13292
# After epoch: 44600; loss:  0.13291
# After epoch: 44700; loss:  0.13291
# After epoch: 44800; loss:  0.13291
# After epoch: 44900; loss:  0.13291
# After epoch: 45000; loss:  0.13290
# After epoch: 45100; loss:  0.13290
# After epoch: 45200; loss:  0.13290
# After epoch: 45300; loss:  0.13290
# After epoch: 45400; loss:  0.13289
# After epoch: 45500; loss:  0.13289
# After epoch: 45600; loss:  0.13289
# After epoch: 45700; loss:  0.13289
# After epoch: 45800; loss:  0.13288
# After epoch: 45900; loss:  0.13288
# After epoch: 46000; loss:  0.13288
# After epoch: 46100; loss:  0.13288
# After epoch: 46200; loss:  0.13287
# After epoch: 46300; loss:  0.13287
# After epoch: 46400; loss:  0.13287
# After epoch: 46500; loss:  0.13286
# After epoch: 46600; loss:  0.13286
# After epoch: 46700; loss:  0.13286
# After epoch: 46800; loss:  0.13286
# After epoch: 46900; loss:  0.13285
# After epoch: 47000; loss:  0.13285
# After epoch: 47100; loss:  0.13285
# After epoch: 47200; loss:  0.13285
# After epoch: 47300; loss:  0.13284
# After epoch: 47400; loss:  0.13284
# After epoch: 47500; loss:  0.13284
# After epoch: 47600; loss:  0.13284
# After epoch: 47700; loss:  0.13283
# After epoch: 47800; loss:  0.13283
# After epoch: 47900; loss:  0.13283
# After epoch: 48000; loss:  0.13283
# After epoch: 48100; loss:  0.13282
# After epoch: 48200; loss:  0.13282
# After epoch: 48300; loss:  0.13282
# After epoch: 48400; loss:  0.13282
# After epoch: 48500; loss:  0.13281
# After epoch: 48600; loss:  0.13281
# After epoch: 48700; loss:  0.13281
# After epoch: 48800; loss:  0.13281
# After epoch: 48900; loss:  0.13280
# After epoch: 49000; loss:  0.13280
# After epoch: 49100; loss:  0.13280
# After epoch: 49200; loss:  0.13280
# After epoch: 49300; loss:  0.13279
# After epoch: 49400; loss:  0.13279
# After epoch: 49500; loss:  0.13279
# After epoch: 49600; loss:  0.13278
# After epoch: 49700; loss:  0.13278
# After epoch: 49800; loss:  0.13278
# After epoch: 49900; loss:  0.13278

# %%
plt.plot(loss_hist['epoch'], loss_hist['loss'])

# %%
model
# Out:
# {'W1': array([[ 2.97245413,  1.15200886,  1.89066828, -4.18868915],
#         [-1.00305096,  0.52044151,  1.47258211,  1.78242586]]),
#  'b1': array([[-3.8267303 , -0.45281076, -1.313162  , -2.1584508 ]],
#        dtype=float32),
#  'W2': array([[-4.26179939,  4.52206169],
#         [ 0.37443732, -0.0309703 ],
#         [ 5.03333596, -4.22843896],
#         [ 3.88334698, -3.49264238]]),
#  'b2': array([[-0.37460086,  0.37460086]], dtype=float32)}

# %%
y_pred = predict(model, X_test)

print(accuracy_score(np.argmax(y_test, axis=1), y_pred))
# Out:
# 0.985

# %%
# cm = confusion_matrix(y_test, y_pred)
# cm

# %%
# disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    
# fig, ax = plt.subplots(figsize = (6,6))

# disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)
# # Disable the grid
# ax.grid(False)

# plt.show();

# %%
# fig, ax = plt.subplots()
# ax.plot(errors);

# # little beautification
# txtstr = "Training Error: \n  Start : {:7.2f}\n   End : {:7.2f}".format(errors[0],errors[-1]) #text to plot

# # properties  matplotlib.patch.Patch 
# props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# # place a text box in upper right in axes coords
# ax.text(0.75, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
#         verticalalignment='top', bbox=props)

# ax.set_xlabel("Epochs")

# ax.set_ylabel("Error")

# ax.grid();

# %%
X = X_train

fig, ax = plt.subplots()
dm = 0.005 # Smoothen the curve

X_min, X_max = X[:,0].min() - 0.05, X[:,0].max() + 0.05
y_min, y_max = X[:,1].min() - 0.05, X[:,1].max() + 0.05

xx, yy = np.meshgrid(np.arange(X_min, X_max, dm),
                     np.arange(y_min, y_max, dm))

XX = np.c_[xx.ravel(), yy.ravel()]
# XX = np.hstack((XX, np.ones((XX.shape[0],1))))

# prediction = predict(model, XX)
# y_pred = prediction.argmax(axis = 1)

y_pred = predict(model, XX)

# for row in XX:
#     pred = predict(row, model)
#     y_pred.append(np.round(pred)) # to get only 2 sections in the contour, we used np.round(pred)

Z = np.array(y_pred).reshape(xx.shape)

ax.contourf(xx, yy, Z, cmap=CMAP, alpha=0.8)
ax.scatter(X[:,0], X[:,1], c = y_train.argmax(axis=1),edgecolors='k', cmap=plt.cm.bwr, marker='o');

# %%
xx.shape, yy.shape
# Out:
# ((534, 780), (534, 780))

# %% [markdown]
# Training Accuracy

# %%
predictions = []

for row in data_train:
    
    a = predict(row, weights)
    
    prediction = 0
    
    if a >= 0.5: prediction = 1 # argmax

    predictions.append(prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 predictions = []
# ----> 3 for row in data_train:
#       5     a = predict(row, weights)
#       7     prediction = 0
#
# NameError: name 'data_train' is not defined

# %%
accuracy_score(data_train[:,-1], predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 accuracy_score(data_train[:,-1], predictions)
#
# NameError: name 'data_train' is not defined

# %% [markdown]
# Testing Accuracy

# %%
predictions = []

for row in data_test:
    
    a = predict(row, weights)
    
    prediction = 0
    
    if a >= 0.5: prediction = 1
    predictions.append(prediction)

accuracy_score(data_test[:,-1], predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 predictions = []
# ----> 3 for row in data_test:
#       5     a = predict(row, weights)
#       7     prediction = 0
#
# NameError: name 'data_test' is not defined

# %%
cm = confusion_matrix(data_test[:, -1], predictions)
cm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 cm = confusion_matrix(data_test[:, -1], predictions)
#       2 cm
#
# NameError: name 'data_test' is not defined

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    
fig, ax = plt.subplots(figsize = (6,6))

disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)
# Disable the grid
ax.grid(False)

plt.show();
